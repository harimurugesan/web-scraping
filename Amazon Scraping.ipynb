# %%
import requests
from  bs4 import BeautifulSoup
res = requests.get("https://www.amazon.in/Dennis-Lingo-Solid-Casual-CC201_Dustypink_M_Dustypink_M/dp/B01N9OTU7H/ref=sr_1_10?dchild=1&keywords=men%2Bshirt&qid=1580102496&sr=8-10&th=1")
soup = BeautifulSoup(res.text,"html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html lang="en-us" class="a-no-js a-lt-ie9 a-lt-ie8 a-lt-ie7"> <![endif]-->
# <!--[if IE 7]>    <html lang="en-us" class="a-no-js a-lt-ie9 a-lt-ie8"> <![endif]-->
# <!--[if IE 8]>    <html lang="en-us" class="a-no-js a-lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="a-no-js" lang="en-us">
#  <!--<![endif]-->
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <title dir="ltr">
#    Robot Check
#   </title>
#   <meta content="width=device-width" name="viewport"/>
#   <link href="https://images-na.ssl-images-amazon.com/images/G/01/AUIClients/AmazonUI-3c913031596ca78a3768f4e934b1cc02ce238101.secure.min._V1_.css" rel="stylesheet"/>
#   <script>
#    if (true === true) {
#     var ue_t0 = (+ new Date()),
#         ue_csm = window,
#         ue = { t0: ue_t0, d: function() { return (+new Date() - ue_t0); } },
# ...

# %%
import urllib.request
url = "https://www.amazon.in/Dennis-Lingo-Solid-Casual-CC201_Dustypink_M_Dustypink_M/dp/B01N9OTU7H/ref=sr_1_10?dchild=1&keywords=men%2Bshirt&qid=1580102496&sr=8-10&th=1"
user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.47 Safari/537.36'
request = urllib.request.Request(url,headers={'User-Agent': user_agent})
response = urllib.request.urlopen(request)
html = response.read()
soup = BeautifulSoup(html,"lxml")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo">
#  <head>
#   <script type="text/javascript">
#    var ue_t0=ue_t0||+new Date();
#   </script>
#   <script type="text/javascript">
#    window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
# var ue_hob=+new Date();
# var ue_id='H4ARY78AHF87VEP2JR54',
# ue_csm = window,
# ue_err_chan = 'jserr-rw',
# ue = {};
# (function(d){var e=d.ue=d.ue||{},f=Date.now||function(){return+new Date};e.d=function(b){return f()-(b?0:d.ue_t0)};e.stub=function(b,a){if(!b[a]){var c=[];b[a]=function(){c.push([c.slice.call(arguments),e.d(),d.ue_id])};b[a].replay=function(b){for(var a;a=c.shift();)b(a[0],a[1],a[2])};b[a].isStub=1}};e.exec=function(b,a){return function(){try{return b.apply(this,arguments)}catch(c){ueLogError(c,{attribution:a||"undefined",logLevel:"WARN"})}}}})(ue_csm);
#
# ue.stub(ue,"log");ue.stub(ue,"onunload");ue.stub(ue,"onflush");
#
# ...

# %%
soup.find('span',attrs = {"id":"productTitle"}).text.strip()
# Out:
# "Dennis Lingo Men's Casual Shirt"

# %%
colour_img = {}
for i in soup.find_all('ul',attrs={"class":"a-unordered-list a-nostyle a-button-list a-declarative a-button-toggle-group a-horizontal a-spacing-top-micro swatches swatchesRectangle imageSwatches"}):
    for j in i.find_all("img",attrs={"class":"imgSwatch"}):
        colour_img[j['alt']] = j['src']
colour_img
# Out:
# {'Brown': 'https://images-na.ssl-images-amazon.com/images/I/41FjjQ-zBAL._SX38_SY50_CR,0,0,38,50_.jpg',
#  'Burgundy': 'https://images-na.ssl-images-amazon.com/images/I/41jFmYwPfuL._SX38_SY50_CR,0,0,38,50_.jpg',
#  'Dustygreen': 'https://images-na.ssl-images-amazon.com/images/I/41MV1PebdlL._SX38_SY50_CR,0,0,38,50_.jpg',
#  'Dustyorange': 'https://images-na.ssl-images-amazon.com/images/I/41CLoz2WMNL._SX38_SY50_CR,0,0,38,50_.jpg',
#  'Dustypink': 'https://images-na.ssl-images-amazon.com/images/I/41d7Y8fFY0L._SX38_SY50_CR,0,0,38,50_.jpg',
#  'Grey': 'https://images-na.ssl-images-amazon.com/images/I/41fGFxm6WuL._SX38_SY50_CR,0,0,38,50_.jpg',
#  'Lemon': 'https://images-na.ssl-images-amazon.com/images/I/41lyotLALGL._SX38_SY50_CR,0,0,38,50_.jpg',
#  'P-Blue': 'https://images-na.ssl-images-amazon.com/images/I/41TP%2BnrtwyL._SX38_SY50_CR,0,0,38,50_.jpg',
#  'Peach': 'https://images-na.ssl-images-amazon.com/images/I/41cdRw9muDL._SX38_SY50_CR,0,0,38,50_.jpg',
# ...

# %%
 for j in soup.find_all("option",attrs={"class":"dropdownAvailable"}):
        print(j.text.strip())
# Out:
# S
# M
# L
# XL
# XXL

# %%
import requests
from  bs4 import BeautifulSoup
res = requests.get("https://www.ah.nl/producten/aardappel-groente-fruit")
soup = BeautifulSoup(res.text,"html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html>
#  <head>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <title data-react-helmet="true">
#    Aardappel, groente, fruit bestellen | Albert Heijn
#   </title>
#   <meta content="ie=edge" data-react-helmet="true" http-equiv="x-ua-compatible">
#    <meta charset="utf-8" data-react-helmet="true"/>
#    <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" data-react-helmet="true" name="viewport"/>
#    <meta content="#564237" data-react-helmet="true" name="msapplication-TileColor"/>
#    <meta content="1.6" data-react-helmet="true" name="settings:cookie-version"/>
#    <meta content="/zoeken/assets/browserconfig.xml?v=wAOeOR32dY" data-react-helmet="true" name="msapplication-config"/>
#    <meta content="#ffffff" data-react-helmet="true" name="theme-color"/>
#    <meta content="index,follow" data-react-helmet="true" name="robots"/>
# ...

# %% [markdown]
# # amazon scraping

# %%
import urllib.request
from  bs4 import BeautifulSoup
url = "https://www.amazon.in/Jockey-2714-0105-BLACK-Black-XL-2714-0105-BLACK_Black_XL/dp/B01CE7WJP0"
user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.47 Safari/537.36'
request = urllib.request.Request(url,headers={'User-Agent': user_agent})
response = urllib.request.urlopen(request)
html = response.read()
soup = BeautifulSoup(html,"lxml")
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html class="a-no-js" data-19ax5a9jf="dingo">\n <head>\n  <script type="text/javascript">\n   var ue_t0=ue_t0||+new Date();\n  </script>\n  <script type="text/javascript">\n   window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;\nif (window.ue_ihb === 1) {\nvar ue_hob=+new Date();\nvar ue_id=\'WTPVTNH2S35YW79BKZWP\',\nue_csm = window,\nue_err_chan = \'jserr-rw\',\nue = {};\n(function(d){var e=d.ue=d.ue||{},f=Date.now||function(){return+new Date};e.d=function(b){return f()-(b?0:d.ue_t0)};e.stub=function(b,a){if(!b[a]){var c=[];b[a]=function(){c.push([c.slice.call(arguments),e.d(),d.ue_id])};b[a].replay=function(b){for(var a;a=c.shift();)b(a[0],a[1],a[2])};b[a].isStub=1}};e.exec=function(b,a){return function(){try{return b.apply(this,arguments)}catch(c){ueLogError(c,{attribution:a||"undefined",logLevel:"WARN"})}}}})(ue_csm);\n\nue.stub(ue,"log");ue.stub(ue,"onunload");ue.stub(ue,"onflush");\n\n(function(d,e){function h(f,b){if(!(a.ec>a.mxe)&&f){a.ter.push(f);b=b
# ...

# %%
user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.47 Safari/537.36'
def url_open(url):
    request = urllib.request.Request(url,headers={'User-Agent': user_agent})
    response = urllib.request.urlopen(request)
    html = response.read()
    soup_1 = BeautifulSoup(html,"lxml")
    return soup

# %%
colour = []
for i in soup.find("ul",attrs = {"class":"a-unordered-list a-nostyle a-button-list a-declarative a-button-toggle-group a-horizontal a-spacing-top-micro swatches swatchesRec\
tangle imageSwatches"}).find_all('li'):
    colour.append(i['data-defaultasin'])
colour
# Out:
# ['B012SSUEJ8',
#  'B012SSWGJO',
#  'B01CE7WJP0',
#  'B01CE7WONW',
#  'B01J9JFPHU',
#  'B072HMPLX7',
#  'B012STE3CQ',
#  'B01CE7WR5W',
#  'B012STK2AS',
#  'B012STP7EO',
#  'B012SSY3F4',
#  'B012ST5NCA',
#  'B01CE7WWKW',
#  'B012SSZU88',
#  'B01CE7WWHA']

# %%
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions
from selenium.common.exceptions import NoSuchElementException
import selenium
import time
import pandas as pd

# %%
img_link = []
url = "https://www.amazon.in/Jockey-2714-0105-BLACK-Black-XL-2714-0105-BLACK_Black_XL/dp/B01CE7WJP0"
soup_1 = url_open(url)
for i in soup_1.find_all("span",attrs = {"class":"a-button-text"}):
    img = i.find('img')
    if img:
        img_link.append(img['src'])

img_link = img_link[:-1]
img_link
# Out:
# ['https://images-na.ssl-images-amazon.com/images/I/41yOO%2B3-FNL._SR38,50_.jpg',
#  'https://images-na.ssl-images-amazon.com/images/I/41PP7ehrjdL._SR38,50_.jpg',
#  'https://images-na.ssl-images-amazon.com/images/I/41NCC7Myu2L._SR38,50_.jpg',
#  'https://images-na.ssl-images-amazon.com/images/I/41d5FV6ufXL._SR38,50_.jpg']

# %%
#/span[@id='productTitle']
soup.find("span",attrs = {"id":"productTitle"}).get_text().strip()
# Out:
# "Jockey Men's Cotton T-Shirt"

# %%
soup_1.find("span",attrs ={"id":'priceblock_ourprice'})
# Out:
# <span class="a-size-medium a-color-price priceBlockBuyingPriceString" id="priceblock_ourprice">₹ 340.00 - ₹ 599.00</span>

# %%
available = []
colour_name = soup_1.find("span",attrs ={"class":'selection'}).get_text().strip()
title = soup.find("span",attrs = {"id":"productTitle"}).get_text().strip()
for i in soup_1.find_all('select',attrs={"id":"native_dropdown_selected_size_name"})[0].find_all('option')[1:]:
    if i['class'][0] == "dropdownAvailable":
        available.append([title,img_link,colour_name ,i.get_text().strip(),"available"])
    if i['class'][0] == "dropdownUnavailable":
        available.append([title,img_link,colour_name ,i.get_text().strip(),'not available'])
print(available)
# Out:
# [["Jockey Men's Cotton T-Shirt", ['https://images-na.ssl-images-amazon.com/images/I/41yOO%2B3-FNL._SR38,50_.jpg', 'https://images-na.ssl-images-amazon.com/images/I/41PP7ehrjdL._SR38,50_.jpg', 'https://images-na.ssl-images-amazon.com/images/I/41NCC7Myu2L._SR38,50_.jpg', 'https://images-na.ssl-images-amazon.com/images/I/41d5FV6ufXL._SR38,50_.jpg'], 'Burnt Gold', 'S', 'available'], ["Jockey Men's Cotton T-Shirt", ['https://images-na.ssl-images-amazon.com/images/I/41yOO%2B3-FNL._SR38,50_.jpg', 'https://images-na.ssl-images-amazon.com/images/I/41PP7ehrjdL._SR38,50_.jpg', 'https://images-na.ssl-images-amazon.com/images/I/41NCC7Myu2L._SR38,50_.jpg', 'https://images-na.ssl-images-amazon.com/images/I/41d5FV6ufXL._SR38,50_.jpg'], 'Burnt Gold', 'M', 'available'], ["Jockey Men's Cotton T-Shirt", ['https://images-na.ssl-images-amazon.com/images/I/41yOO%2B3-FNL._SR38,50_.jpg', 'https://images-na.ssl-images-amazon.com/images/I/41PP7ehrjdL._SR38,50_.jpg', 'https://images-na.ssl-images-amazon.com/ima
# ...

# %%
driver = selenium.webdriver.Chrome(executable_path="D:\chromedriver.exe")
driver.get(url)
total_sizes = len(soup_1.find_all('select',attrs={"id":"native_dropdown_selected_size_name"})[0].find_all('option'))
print(total_sizes)
for i in range(1,total_sizes):
    obj = Select(driver.find_element_by_id('native_dropdown_selected_size_name'))
    obj.select_by_index(i)
    time.sleep(2)
    html = driver.page_source
    soup_1 = BeautifulSoup(html,"lxml")
    try:
        if available[i-1][-1] == 'available':
            txt = soup_1.find("span",attrs ={"id":'priceblock_ourprice'}).get_text().strip().split()[1]
        else:
            txt = ''
    except:
         txt = ''   
    available[i-1].append(txt)
available
# Out:
# 6
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-126-26321f5c8b2e> in <module>
#      10     soup_1 = BeautifulSoup(html,"lxml")
#      11     if available[i-1][-1] == 'available':
# ---> 12         txt = soup_1.find("span",attrs ={"id":'priceblock_ourprice'}).get_text().strip().split()[1]
#      13     else:
#      14         txt = ''
#
# AttributeError: 'NoneType' object has no attribute 'get_text'

# %%
import urllib.request
from  bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions
from selenium.common.exceptions import NoSuchElementException
import selenium
import time
import pandas as pd

user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.47 Safari/537.36'
def url_open(url):
    request = urllib.request.Request(url,headers={'User-Agent': user_agent})
    response = urllib.request.urlopen(request)
    html = response.read()
    soup_1 = BeautifulSoup(html,"lxml")
    return soup_1

available_result = []
colour = []
driver = selenium.webdriver.Chrome(executable_path="D:\chromedriver.exe")
url = "https://www.amazon.in/Jockey-2714-0105-BLACK-Black-XL-2714-0105-BLACK_Black_XL/dp/B071YSSRDR/"
soup = url_open(url)
title = soup.find("span",attrs = {"id":"productTitle"}).get_text().strip()
for i in soup.find("ul",attrs = {"class":"a-unordered-list a-nostyle a-button-list a-declarative a-button-toggle-group a-horizontal a-spacing-top-micro swatches swatchesRec\
tangle imageSwatches"}).find_all('li'):
    colour.append(i['data-defaultasin'])

for col in colour:
    url = "https://www.amazon.in/Jockey-2714-0105-BLACK-Black-XL-2714-0105-BLACK_Black_XL/dp/{}".format(col)
    print(url)
    soup_1 = url_open(url)
    img_link = []
    for i in soup_1.find_all("span",attrs = {"class":"a-button-text"}):
        img = i.find('img')
        if img:
            img_link.append(img['src'])

    img_link = img_link[:-1]
    available = []
    colour_name = soup_1.find("span",attrs ={"class":'selection'}).get_text().strip()
    for i in soup_1.find_all('select',attrs={"id":"native_dropdown_selected_size_name"})[0].find_all('option')[1:]:
        if i['class'][0] == "dropdownAvailable":
            available.append([title,url,img_link,colour_name ,i.get_text().strip(),"available"])
        if i['class'][0] == "dropdownUnavailable":
            available.append([title,url,img_link,colour_name ,i.get_text().strip(),'not available'])
    driver.get(url)
    total_sizes = len(soup_1.find_all('select',attrs={"id":"native_dropdown_selected_size_name"})[0].find_all('option'))
    #print(total_sizes)
    for i in range(1,total_sizes):
        obj = Select(driver.find_element_by_id('native_dropdown_selected_size_name'))
        obj.select_by_index(i)
        time.sleep(2)
        html = driver.page_source
        soup_1 = BeautifulSoup(html,"lxml")
        #print(available[i-1])
        try:
            if available[i-1][-1] == 'available':
                txt = soup_1.find("span",attrs ={"id":'priceblock_ourprice'}).get_text().strip().split()[1]
            else:
                txt = ''
        except:
             txt = ''   
        available[i-1].append(txt)
    available_result += available.copy()
available_result
# Out:
# https://www.amazon.in/Jockey-2714-0105-BLACK-Black-XL-2714-0105-BLACK_Black_XL/dp/B012SSUEJ8
# https://www.amazon.in/Jockey-2714-0105-BLACK-Black-XL-2714-0105-BLACK_Black_XL/dp/B012SSWGJO
# https://www.amazon.in/Jockey-2714-0105-BLACK-Black-XL-2714-0105-BLACK_Black_XL/dp/B01CE7WJP0
# https://www.amazon.in/Jockey-2714-0105-BLACK-Black-XL-2714-0105-BLACK_Black_XL/dp/B01CE7WONW
# https://www.amazon.in/Jockey-2714-0105-BLACK-Black-XL-2714-0105-BLACK_Black_XL/dp/B01J9JFPHU
# https://www.amazon.in/Jockey-2714-0105-BLACK-Black-XL-2714-0105-BLACK_Black_XL/dp/B072HMPLX7
# https://www.amazon.in/Jockey-2714-0105-BLACK-Black-XL-2714-0105-BLACK_Black_XL/dp/B012STE3CQ
# https://www.amazon.in/Jockey-2714-0105-BLACK-Black-XL-2714-0105-BLACK_Black_XL/dp/B01CE7WR5W
# https://www.amazon.in/Jockey-2714-0105-BLACK-Black-XL-2714-0105-BLACK_Black_XL/dp/B012STK2AS
# https://www.amazon.in/Jockey-2714-0105-BLACK-Black-XL-2714-0105-BLACK_Black_XL/dp/B012STP7EO
# ...

# %%
df = pd.DataFrame(available_result,columns = ['product','url',"image","colour","size","availablity","price"])
df.head()
# Out:
#                        product  \
# 0  Jockey Men's Cotton T-Shirt
# 1  Jockey Men's Cotton T-Shirt
# 2  Jockey Men's Cotton T-Shirt
# 3  Jockey Men's Cotton T-Shirt
# 4  Jockey Men's Cotton T-Shirt
#
#                                                  url  \
# 0  https://www.amazon.in/Jockey-2714-0105-BLACK-B...
# 1  https://www.amazon.in/Jockey-2714-0105-BLACK-B...
# 2  https://www.amazon.in/Jockey-2714-0105-BLACK-B...
# 3  https://www.amazon.in/Jockey-2714-0105-BLACK-B...
# 4  https://www.amazon.in/Jockey-2714-0105-BLACK-B...
#
#                                                image     colour size  \
# 0  [https://images-na.ssl-images-amazon.com/image...  Azur Blue    S
# 1  [https://images-na.ssl-images-amazon.com/image...  Azur Blue    M
# 2  [https://images-na.ssl-images-amazon.com/image...  Azur Blue    L
# 3  [https://images-na.ssl-images-amazon.com/image...  Azur Blue   XL
# 4  [https://images-na.ssl-images-amazon.com/image...  Azur Blue  2XL
#
#   availablity   price
# ...

# %%
df
# Out:
#                         product  \
# 0   Jockey Men's Cotton T-Shirt
# 1   Jockey Men's Cotton T-Shirt
# 2   Jockey Men's Cotton T-Shirt
# 3   Jockey Men's Cotton T-Shirt
# 4   Jockey Men's Cotton T-Shirt
# 5   Jockey Men's Cotton T-Shirt
# 6   Jockey Men's Cotton T-Shirt
# 7   Jockey Men's Cotton T-Shirt
# 8   Jockey Men's Cotton T-Shirt
# 9   Jockey Men's Cotton T-Shirt
# 10  Jockey Men's Cotton T-Shirt
# 11  Jockey Men's Cotton T-Shirt
# 12  Jockey Men's Cotton T-Shirt
# 13  Jockey Men's Cotton T-Shirt
# 14  Jockey Men's Cotton T-Shirt
# 15  Jockey Men's Cotton T-Shirt
# 16  Jockey Men's Cotton T-Shirt
# 17  Jockey Men's Cotton T-Shirt
# 18  Jockey Men's Cotton T-Shirt
# 19  Jockey Men's Cotton T-Shirt
# 20  Jockey Men's Cotton T-Shirt
# 21  Jockey Men's Cotton T-Shirt
# 22  Jockey Men's Cotton T-Shirt
# 23  Jockey Men's Cotton T-Shirt
# 24  Jockey Men's Cotton T-Shirt
# 25  Jockey Men's Cotton T-Shirt
# 26  Jockey Men's Cotton T-Shirt
# 27  Jockey Men's Cotton T-Shirt
# ...

# %%
soup.find("ul",attrs = {"class":"a-unordered-list a-nostyle a-button-list a-declarative a-button-toggle-group a-horizontal a-spacing-top-micro swatches swatchesRec\
tangle imageSwatches"}).find("li").contents
# Out:
# [<span class="a-list-item">
#  <div class="tooltip">
#  <span class="a-declarative" data-action="swatchthumb-action" data-swatchthumb-action='{"dimIndex":1,"dimValueIndex":0}'>
#  <span class="a-button a-button-thumbnail a-button-toggle"><span class="a-button-inner"><button class="a-button-text" type="button">
#  <span class="xoverlay"></span>
#  <div class="">
#  <div class="">
#  <img alt="Azur Blue" class="imgSwatch" src="https://images-na.ssl-images-amazon.com/images/I/41QPNH95fgL._SX38_SY50_CR,0,0,38,50_.jpg" style="height:50px; width:38px"/>
#  </div>
#  <div class="" style="">
#  </div>
#  </div>
#  </button></span></span>
#  </span>
#  </div>
#  <a href="/dp/B012SSUEJ8/ref=twister_B012T0S7M6" style="height:100%; width:100%"></a>
#  </span>]
